# %%
pip install rasterio numpy
# Out:
# Requirement already satisfied: rasterio in c:\users\febin\anaconda3\lib\site-packages (1.4.3)
# Requirement already satisfied: numpy in c:\users\febin\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: affine in c:\users\febin\anaconda3\lib\site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in c:\users\febin\anaconda3\lib\site-packages (from rasterio) (23.1.0)
# Requirement already satisfied: certifi in c:\users\febin\anaconda3\lib\site-packages (from rasterio) (2025.1.31)
# Requirement already satisfied: click>=4.0 in c:\users\febin\anaconda3\lib\site-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in c:\users\febin\anaconda3\lib\site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\febin\anaconda3\lib\site-packages (from rasterio) (1.1.1.2)
# Requirement already satisfied: pyparsing in c:\users\febin\anaconda3\lib\site-packages (from rasterio) (3.1.2)
# Requirement already satisfied: colorama in c:\users\febin\anaconda3\lib\site-packages (from click>=4.0->rasterio) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import rasterio

# %%
red_path = r"C:\Users\febin\Downloads\S2B_MSIL2A_20240515T101559_N0510_R065_T32UNA_20240515T162822.SAFE\GRANULE\L2A_T32UNA_A037557_20240515T102620\IMG_DATA\R10m\T32UNA_20240515T101559_B04_10m.jp2"
with rasterio.open(red_path) as src:
    red = src.read(1)

# %%
plt.imshow(red,cmap='gray')
plt.title('Red Band')
plt.colorbar()
plt.show()

# %%
#compute NDVI
nir_path = r"C:\Users\febin\Downloads\S2B_MSIL2A_20240515T101559_N0510_R065_T32UNA_20240515T162822.SAFE\GRANULE\L2A_T32UNA_A037557_20240515T102620\IMG_DATA\R10m\T32UNA_20240515T101559_B08_10m.jp2"
with rasterio.open(nir_path) as src:
    nir = src.read(1)
red=red.astype(float)

ndvi=(nir-red)/(nir+red)


plt.imshow(ndvi,cmap='RdYlGn')
plt.show()
# Out:
# C:\Users\febin\AppData\Local\Temp\ipykernel_12752\3813365527.py:5: RuntimeWarning: invalid value encountered in divide
#   ndvi=(nir-red)/(nir+red)
